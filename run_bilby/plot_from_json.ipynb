# %%
import configparser
import argparse
import os
from single_posterior_plot import plot_posterior

"""set up"""
#recieve the argments from command line
def plot_from_json(config_file_path):

    config_path = config_file_path
    config_ini = configparser.ConfigParser()
    config_ini.read(config_path)

    if not os.path.exists(config_path):
        raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), config_path)
    
    config_setting = config_ini['setting']

    """set the event to be analyzed"""
    event_name = config_setting['event_name']
    #index = config_setting['index']
    #index = 'v1'
    index = None
    if index is not None:
        outdir = 'outdirs/outdir_' + event_name + '_' + index
        label = event_name + '_' + index
    else:
        outdir = 'outdirs/outdir_' + event_name
        label = event_name

    plot_posterior(
                    path_json = outdir+'/'+label+'_result.json',
                    path_outdir = outdir,
                    default_plot_parameters = True,
                    show_fig = True
                    )
# Out:
# /home/hayato.imafuku/research/env/lib/python3.11/site-packages/gwpy/time/__init__.py:36: UserWarning: Wswiglal-redir-stdio:
#
# SWIGLAL standard output/error redirection is enabled in IPython.
# This may lead to performance penalties. To disable locally, use:
#
# with lal.no_swig_redirect_standard_output_error():
#     ...
#
# To disable globally, use:
#
# lal.swig_redirect_standard_output_error(False)
#
# Note however that this will likely lead to error messages from
# LAL functions being either misdirected or lost when called from
# Jupyter notebooks.
#
# To suppress this warning, use:
#
# import warnings
# warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
# import lal
#
#   from lal import LIGOTimeGPS

# %%
config_file_path = 'config/test_one_mode.ini'
plot_from_json(config_file_path)
# Out:
# 23:18 bilby WARNING : Prior sampling efficiency is very low, please verify its validity.
#  injection_parameters : {'A1': 0.4, 'alpha': 0.001, 'f1': 201.0, 'tau1': -0.00332, 'f2': 220.0, 'tau2': -0.003, 'phi1': 0.0, 'phi2': 0.0, 'ra': 0.0, 'dec': 0.0, 'psi': 0.0, 'geocent_time': 0.0, 'reference_frequency': 50.0, 'minimum_frequency': 20.0, 'phi_jl': 0.0, 'phi_12': 0.0, 'H1_matched_filter_snr': (35.63524815613223-0.06918612338107097j), 'H1_optimal_snr': 36.62314935478983, 'L1_matched_filter_snr': (45.215827519888485-1.2080472868114212j), 'L1_optimal_snr': 44.896815994619594, 'V1_matched_filter_snr': (19.35236458557967-0.7782032737173976j), 'V1_optimal_snr': 20.429305472525016, 'fix_list': ['ra', 'dec', 'psi', 'geocent_time'], 'log_likelihood': nan, 'log_prior': nan, 'H1_log_likelihood': nan, 'L1_log_likelihood': nan, 'V1_log_likelihood': nan}
# plot key : A1
# plot key : f1
# plot key : tau1
# plot key : phi1
# not plot key : alpha
# not plot key : f2
# not plot key : tau2
# not plot key : phi2
# not plot key : ra
# not plot key : dec
# not plot key : psi
# not plot key : geocent_time
# A1 0.4
# f1 201.0
# tau1 -0.00332
# phi1 0.0
# create posterior plot from: outdirs/outdir_test_new_parameterizartion_v4/test_new_parameterizartion_v4_result.json
