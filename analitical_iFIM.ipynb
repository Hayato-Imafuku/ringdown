# %% [markdown]
# # The results of FIM from mathematica
#
# correlation coefficients
#
# In[43]:= CorrCoef[x_Integer, y_Integer] :=
#  Simplify[invFIM[[x, y]] / Sqrt[invFIM[[x, x]] invFIM[[y, y]]]]
#
# In[85]:= (*A1A2*)
# CA1A2 = CorrCoef[1, 2]
#
# Out[85]= (8 tau1 tau2 ((tau1 + tau2) (tau2^2 +
#         4 (f1 - f2)^2 \[Pi]^2 tau1^3 tau2 (1 + 4 f1^2 \[Pi]^2 tau2^2 -
#            8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#         tau1^2 (1 + 12 f1^2 \[Pi]^2 tau2^2 - 24 f1 f2 \[Pi]^2 tau2^2 +
#            12 f2^2 \[Pi]^2 tau2^2) +
#         tau1 (6 tau2 + 4 (f1 - f2)^2 \[Pi]^2 tau2^3)) Cos[
#        phi1 - phi2] - (f1 - f2) \[Pi] (6 tau1^2 tau2^2 - 2 tau1 tau2^3 -
#         tau2^4 + 2 tau1^3 tau2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 -
#            8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#         tau1^4 (-1 + 16 f1^4 \[Pi]^4 tau2^4 - 64 f1^3 f2 \[Pi]^4 tau2^4 +
#            96 f1^2 f2^2 \[Pi]^4 tau2^4 - 64 f1 f2^3 \[Pi]^4 tau2^4 +
#            16 f2^4 \[Pi]^4 tau2^4)) Sin[phi1 - phi2]))/((-2 tau1 tau2 +
#      tau2^2 + tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2))^3 \[Sqrt](1/(
#       tau1 tau2 (-2 tau1 tau2 + tau2^2 +
#          tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#             4 f2^2 \[Pi]^2 tau2^2))^6) (2 tau1 tau2 + tau2^2 +
#          tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#             4 f2^2 \[Pi]^2 tau2^2))^2 (8 tau1 tau2^3 + tau2^4 +
#          8 tau1^3 tau2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#             4 f2^2 \[Pi]^2 tau2^2) +
#          tau1^4 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#             4 f2^2 \[Pi]^2 tau2^2)^2 +
#          2 tau1^2 tau2^2 (15 + 4 f1^2 \[Pi]^2 tau2^2 -
#             8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2)) (-8 tau1 tau2^3 +
#           tau2^4 +
#          tau1^4 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#             4 f2^2 \[Pi]^2 tau2^2)^2 +
#          2 tau1^2 tau2^2 (15 + 4 f1^2 \[Pi]^2 tau2^2 -
#             8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#          8 tau1^3 (tau2 + 4 (f1 - f2)^2 \[Pi]^2 tau2^3))))
#
# In[48]:= (*A1f1*)
# CA1f1 = CorrCoef[1, 3]
#
# Out[48]= (16 Sqrt[2] (f1 - f2) \[Pi] tau2^3 (2 tau1 tau2 + tau2^2 +
#      tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2)))/(A1 (-2 tau1 tau2 + tau2^2 +
#      tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2))^3 \[Sqrt](((2 tau1 tau2 + tau2^2 +
#           tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2))^3 (-8 tau1 tau2^3 + tau2^4 +
#           tau1^4 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2)^2 +
#           2 tau1^2 tau2^2 (15 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#           8 tau1^3 (tau2 +
#              4 (f1 - f2)^2 \[Pi]^2 tau2^3)))/(A1^2 tau1^4 (-2 tau1 tau2 +
#           tau2^2 + tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2))^5)))
#
# In[49]:= (*A1f2*)
# CA1f2 = CorrCoef[1, 4]
#
# Out[49]= -((2 Sqrt[2]
#       tau1 (2 (f1 - f2) \[Pi] tau2 (-4 tau1^2 tau2^2 + 2 tau1 tau2^3 -
#           tau2^4 - 2 tau1^3 tau2 (5 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#           tau1^4 (-3 - 8 f2^2 \[Pi]^2 tau2^2 + 16 f1^4 \[Pi]^4 tau2^4 -
#              64 f1^3 f2 \[Pi]^4 tau2^4 + 16 f2^4 \[Pi]^4 tau2^4 +
#              f1^2 (-8 \[Pi]^2 tau2^2 + 96 f2^2 \[Pi]^4 tau2^4) +
#              f1 (16 f2 \[Pi]^2 tau2^2 - 64 f2^3 \[Pi]^4 tau2^4))) Cos[
#          phi1 - phi2] + (3 tau2^4 +
#           2 tau1^2 tau2^2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#           4 tau1 (tau2^3 + 2 (f1 - f2)^2 \[Pi]^2 tau2^5) +
#           4 tau1^3 tau2 (-1 + 6 f2^2 \[Pi]^2 tau2^2 + 8 f1^4 \[Pi]^4 tau2^4 -
#              32 f1^3 f2 \[Pi]^4 tau2^4 + 8 f2^4 \[Pi]^4 tau2^4 -
#              4 f1 f2 \[Pi]^2 tau2^2 (3 + 8 f2^2 \[Pi]^2 tau2^2) +
#              6 f1^2 (\[Pi]^2 tau2^2 + 8 f2^2 \[Pi]^4 tau2^4)) +
#           tau1^4 (-1 + 8 f2^2 \[Pi]^2 tau2^2 + 48 f1^4 \[Pi]^4 tau2^4 -
#              192 f1^3 f2 \[Pi]^4 tau2^4 + 48 f2^4 \[Pi]^4 tau2^4 +
#              8 f1^2 (\[Pi]^2 tau2^2 + 36 f2^2 \[Pi]^4 tau2^4) -
#              16 f1 (f2 \[Pi]^2 tau2^2 + 12 f2^3 \[Pi]^4 tau2^4))) Sin[
#          phi1 - phi2]))/(A2 tau2 (-2 tau1 tau2 + tau2^2 +
#        tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#           4 f2^2 \[Pi]^2 tau2^2))^3 \[Sqrt](((2 tau1 tau2 + tau2^2 +
#             tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#                4 f2^2 \[Pi]^2 tau2^2))^3 (-8 tau1 tau2^3 + tau2^4 +
#             tau1^4 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#                4 f2^2 \[Pi]^2 tau2^2)^2 +
#             2 tau1^2 tau2^2 (15 + 4 f1^2 \[Pi]^2 tau2^2 -
#                8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#             8 tau1^3 (tau2 +
#                4 (f1 - f2)^2 \[Pi]^2 tau2^3)))/(A2^2 tau1 tau2^\
# 3 (-2 tau1 tau2 + tau2^2 +
#             tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#                4 f2^2 \[Pi]^2 tau2^2))^5))))
#
# In[50]:= (*A1\[Tau]1*)
# CA1\[Tau]1 = CorrCoef[1, 5]
#
# Out[50]= ((2 tau1 tau2 + tau2^2 +
#      tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2)) (-8 tau1 tau2^3 + tau2^4 +
#      2 tau1^2 tau2^2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2) +
#      tau1^4 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2)^2 +
#      8 tau1^3 (tau2 + 4 (f1 - f2)^2 \[Pi]^2 tau2^3)))/(Sqrt[2]
#     A1 (-2 tau1 tau2 + tau2^2 +
#      tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2))^3 \[Sqrt](((2 tau1 tau2 + tau2^2 +
#           tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2))^3 (-8 tau1 tau2^3 + tau2^4 +
#           tau1^4 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2)^2 +
#           2 tau1^2 tau2^2 (15 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#           8 tau1^3 (tau2 +
#              4 (f1 - f2)^2 \[Pi]^2 tau2^3)))/(A1^2 (-2 tau1 tau2 + tau2^2 +
#           tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2))^5)))
#
# In[51]:= (*A1\[Tau]2*)
# CA1\[Tau]2 = CorrCoef[1, 6]
#
# Out[51]= -((2 Sqrt[2]
#       tau1 tau2 ((3 tau2^4 +
#           2 tau1^2 tau2^2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#           4 tau1 (tau2^3 + 2 (f1 - f2)^2 \[Pi]^2 tau2^5) +
#           4 tau1^3 tau2 (-1 + 6 f2^2 \[Pi]^2 tau2^2 + 8 f1^4 \[Pi]^4 tau2^4 -
#              32 f1^3 f2 \[Pi]^4 tau2^4 + 8 f2^4 \[Pi]^4 tau2^4 -
#              4 f1 f2 \[Pi]^2 tau2^2 (3 + 8 f2^2 \[Pi]^2 tau2^2) +
#              6 f1^2 (\[Pi]^2 tau2^2 + 8 f2^2 \[Pi]^4 tau2^4)) +
#           tau1^4 (-1 + 8 f2^2 \[Pi]^2 tau2^2 + 48 f1^4 \[Pi]^4 tau2^4 -
#              192 f1^3 f2 \[Pi]^4 tau2^4 + 48 f2^4 \[Pi]^4 tau2^4 +
#              8 f1^2 (\[Pi]^2 tau2^2 + 36 f2^2 \[Pi]^4 tau2^4) -
#              16 f1 (f2 \[Pi]^2 tau2^2 + 12 f2^3 \[Pi]^4 tau2^4))) Cos[
#          phi1 - phi2] -
#        2 (f1 - f2) \[Pi] tau2 (-4 tau1^2 tau2^2 + 2 tau1 tau2^3 - tau2^4 -
#           2 tau1^3 tau2 (5 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2) +
#           tau1^4 (-3 - 8 f2^2 \[Pi]^2 tau2^2 + 16 f1^4 \[Pi]^4 tau2^4 -
#              64 f1^3 f2 \[Pi]^4 tau2^4 + 16 f2^4 \[Pi]^4 tau2^4 +
#              f1^2 (-8 \[Pi]^2 tau2^2 + 96 f2^2 \[Pi]^4 tau2^4) +
#              f1 (16 f2 \[Pi]^2 tau2^2 - 64 f2^3 \[Pi]^4 tau2^4))) Sin[
#          phi1 - phi2]))/(A2 (-2 tau1 tau2 + tau2^2 +
#        tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#           4 f2^2 \[Pi]^2 tau2^2))^3 \[Sqrt]((tau2 (2 tau1 tau2 + tau2^2 +
#             tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#                4 f2^2 \[Pi]^2 tau2^2))^3 (-8 tau1 tau2^3 + tau2^4 +
#             tau1^4 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#                4 f2^2 \[Pi]^2 tau2^2)^2 +
#             2 tau1^2 tau2^2 (15 + 4 f1^2 \[Pi]^2 tau2^2 -
#                8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#             8 tau1^3 (tau2 +
#                4 (f1 - f2)^2 \[Pi]^2 tau2^3)))/(A2^2 tau1 (-2 tau1 tau2 +
#             tau2^2 + tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 -
#                8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2))^5))))
#
# In[52]:= (*A1\[Phi]1*)
# CA1\[Phi]1 = CorrCoef[1, 7]
#
# Out[52]= 0
#
# In[53]:= (*A1\[Phi]2*)
# CA1\[Phi]2 = CorrCoef[1, 8]
#
# Out[53]= (8 tau1 tau2 ((f1 - f2) \[Pi] (6 tau1^2 tau2^2 - 2 tau1 tau2^3 - tau2^4 +
#         2 tau1^3 tau2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#            4 f2^2 \[Pi]^2 tau2^2) +
#         tau1^4 (-1 + 16 f1^4 \[Pi]^4 tau2^4 - 64 f1^3 f2 \[Pi]^4 tau2^4 +
#            96 f1^2 f2^2 \[Pi]^4 tau2^4 - 64 f1 f2^3 \[Pi]^4 tau2^4 +
#            16 f2^4 \[Pi]^4 tau2^4)) Cos[
#        phi1 - phi2] + (tau1 + tau2) (tau2^2 +
#         4 (f1 - f2)^2 \[Pi]^2 tau1^3 tau2 (1 + 4 f1^2 \[Pi]^2 tau2^2 -
#            8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#         tau1^2 (1 + 12 f1^2 \[Pi]^2 tau2^2 - 24 f1 f2 \[Pi]^2 tau2^2 +
#            12 f2^2 \[Pi]^2 tau2^2) +
#         tau1 (6 tau2 + 4 (f1 - f2)^2 \[Pi]^2 tau2^3)) Sin[
#        phi1 - phi2]))/(A2 (-2 tau1 tau2 + tau2^2 +
#      tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2))^3 \[Sqrt](1/(
#       A2^2 tau1 tau2 (-2 tau1 tau2 + tau2^2 +
#          tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#             4 f2^2 \[Pi]^2 tau2^2))^6) (2 tau1 tau2 + tau2^2 +
#          tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#             4 f2^2 \[Pi]^2 tau2^2))^2 (8 tau1 tau2^3 + tau2^4 +
#          8 tau1^3 tau2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#             4 f2^2 \[Pi]^2 tau2^2) +
#          tau1^4 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#             4 f2^2 \[Pi]^2 tau2^2)^2 +
#          2 tau1^2 tau2^2 (15 + 4 f1^2 \[Pi]^2 tau2^2 -
#             8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2)) (-8 tau1 tau2^3 +
#           tau2^4 +
#          tau1^4 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#             4 f2^2 \[Pi]^2 tau2^2)^2 +
#          2 tau1^2 tau2^2 (15 + 4 f1^2 \[Pi]^2 tau2^2 -
#             8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#          8 tau1^3 (tau2 + 4 (f1 - f2)^2 \[Pi]^2 tau2^3))))
#
# In[54]:= (*A2f1*)
# CA2f1 = CorrCoef[2, 3]
#
# Out[54]= (2 Sqrt[2]
#     tau2 (2 (f1 - f2) \[Pi] tau1 (-10 tau1 tau2^3 - 3 tau2^4 +
#         tau1^3 (2 tau2 - 8 (f1 - f2)^2 \[Pi]^2 tau2^3) -
#         4 tau1^2 (tau2^2 + 2 (f1 - f2)^2 \[Pi]^2 tau2^4) +
#         tau1^4 (-1 + 16 f1^4 \[Pi]^4 tau2^4 - 64 f1^3 f2 \[Pi]^4 tau2^4 +
#            96 f1^2 f2^2 \[Pi]^4 tau2^4 - 64 f1 f2^3 \[Pi]^4 tau2^4 +
#            16 f2^4 \[Pi]^4 tau2^4)) Cos[
#        phi1 - phi2] + (-4 tau1 tau2^3 - tau2^4 +
#         2 tau1^2 tau2^2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 -
#            8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#         8 (f1 - f2)^2 \[Pi]^2 tau1^5 tau2 (1 + 4 f1^2 \[Pi]^2 tau2^2 -
#            8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#         4 tau1^3 (tau2 + 6 (f1 - f2)^2 \[Pi]^2 tau2^3) +
#         tau1^4 (3 + 8 f2^2 \[Pi]^2 tau2^2 + 48 f1^4 \[Pi]^4 tau2^4 -
#            192 f1^3 f2 \[Pi]^4 tau2^4 + 48 f2^4 \[Pi]^4 tau2^4 +
#            8 f1^2 (\[Pi]^2 tau2^2 + 36 f2^2 \[Pi]^4 tau2^4) -
#            16 f1 (f2 \[Pi]^2 tau2^2 + 12 f2^3 \[Pi]^4 tau2^4))) Sin[
#        phi1 - phi2]))/(A1 tau1 (-2 tau1 tau2 + tau2^2 +
#      tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2))^3 \[Sqrt](((2 tau1 tau2 + tau2^2 +
#           tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2))^3 (8 tau1 tau2^3 + tau2^4 +
#           8 tau1^3 tau2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#           tau1^4 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2)^2 +
#           2 tau1^2 tau2^2 (15 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2)))/(A1^2 tau1^3 tau2 (-2 tau1 tau2 +
#           tau2^2 + tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2))^5)))
#
# In[55]:= (*A2f2*)
# CA2f2 = CorrCoef[2, 4]
#
# Out[55]= -((16 Sqrt[
#      2] (f1 - f2) \[Pi] tau1^3 (2 tau1 tau2 + tau2^2 +
#        tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#           4 f2^2 \[Pi]^2 tau2^2)))/(A2 (-2 tau1 tau2 + tau2^2 +
#        tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#           4 f2^2 \[Pi]^2 tau2^2))^3 \[Sqrt](((2 tau1 tau2 + tau2^2 +
#             tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#                4 f2^2 \[Pi]^2 tau2^2))^3 (8 tau1 tau2^3 + tau2^4 +
#             8 tau1^3 tau2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 -
#                8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#             tau1^4 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#                4 f2^2 \[Pi]^2 tau2^2)^2 +
#             2 tau1^2 tau2^2 (15 + 4 f1^2 \[Pi]^2 tau2^2 -
#                8 f1 f2 \[Pi]^2 tau2^2 +
#                4 f2^2 \[Pi]^2 tau2^2)))/(A2^2 tau2^4 (-2 tau1 tau2 + tau2^2 +
#             tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#                4 f2^2 \[Pi]^2 tau2^2))^5))))
#
# In[56]:= (*A2\[Tau]1*)
# CA2\[Tau]1 = CorrCoef[2, 5]
#
# Out[56]= -((2 Sqrt[2]
#       tau1 tau2 ((-4 tau1 tau2^3 - tau2^4 +
#           2 tau1^2 tau2^2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#           8 (f1 - f2)^2 \[Pi]^2 tau1^5 tau2 (1 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#           4 tau1^3 (tau2 + 6 (f1 - f2)^2 \[Pi]^2 tau2^3) +
#           tau1^4 (3 + 8 f2^2 \[Pi]^2 tau2^2 + 48 f1^4 \[Pi]^4 tau2^4 -
#              192 f1^3 f2 \[Pi]^4 tau2^4 + 48 f2^4 \[Pi]^4 tau2^4 +
#              8 f1^2 (\[Pi]^2 tau2^2 + 36 f2^2 \[Pi]^4 tau2^4) -
#              16 f1 (f2 \[Pi]^2 tau2^2 + 12 f2^3 \[Pi]^4 tau2^4))) Cos[
#          phi1 - phi2] -
#        2 (f1 - f2) \[Pi] tau1 (-10 tau1 tau2^3 - 3 tau2^4 +
#           tau1^3 (2 tau2 - 8 (f1 - f2)^2 \[Pi]^2 tau2^3) -
#           4 tau1^2 (tau2^2 + 2 (f1 - f2)^2 \[Pi]^2 tau2^4) +
#           tau1^4 (-1 + 16 f1^4 \[Pi]^4 tau2^4 - 64 f1^3 f2 \[Pi]^4 tau2^4 +
#              96 f1^2 f2^2 \[Pi]^4 tau2^4 - 64 f1 f2^3 \[Pi]^4 tau2^4 +
#              16 f2^4 \[Pi]^4 tau2^4)) Sin[phi1 - phi2]))/(A1 (-2 tau1 tau2 +
#        tau2^2 + tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#           4 f2^2 \[Pi]^2 tau2^2))^3 \[Sqrt]((tau1 (2 tau1 tau2 + tau2^2 +
#             tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#                4 f2^2 \[Pi]^2 tau2^2))^3 (8 tau1 tau2^3 + tau2^4 +
#             8 tau1^3 tau2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 -
#                8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#             tau1^4 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#                4 f2^2 \[Pi]^2 tau2^2)^2 +
#             2 tau1^2 tau2^2 (15 + 4 f1^2 \[Pi]^2 tau2^2 -
#                8 f1 f2 \[Pi]^2 tau2^2 +
#                4 f2^2 \[Pi]^2 tau2^2)))/(A1^2 tau2 (-2 tau1 tau2 + tau2^2 +
#             tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#                4 f2^2 \[Pi]^2 tau2^2))^5))))
#
# In[57]:= (*A2\[Tau]2*)
# CA2\[Tau]2 = CorrCoef[2, 6]
#
# Out[57]= ((2 tau1 tau2 + tau2^2 +
#      tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2)) (8 tau1 tau2^3 + tau2^4 +
#      8 tau1^3 tau2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2) +
#      2 tau1^2 tau2^2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2) +
#      tau1^4 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2)^2))/(Sqrt[2]
#     A2 (-2 tau1 tau2 + tau2^2 +
#      tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2))^3 \[Sqrt](((2 tau1 tau2 + tau2^2 +
#           tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2))^3 (8 tau1 tau2^3 + tau2^4 +
#           8 tau1^3 tau2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#           tau1^4 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2)^2 +
#           2 tau1^2 tau2^2 (15 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2)))/(A2^2 (-2 tau1 tau2 + tau2^2 +
#           tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2))^5)))
#
# In[58]:= (*A2\[Phi]1*)
# CA2\[Phi]1 = CorrCoef[2, 7]
#
# Out[58]= -((8 tau1 tau2 ((f1 - f2) \[Pi] (6 tau1^2 tau2^2 - 2 tau1 tau2^3 - tau2^4 +
#           2 tau1^3 tau2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#           tau1^4 (-1 + 16 f1^4 \[Pi]^4 tau2^4 - 64 f1^3 f2 \[Pi]^4 tau2^4 +
#              96 f1^2 f2^2 \[Pi]^4 tau2^4 - 64 f1 f2^3 \[Pi]^4 tau2^4 +
#              16 f2^4 \[Pi]^4 tau2^4)) Cos[
#          phi1 - phi2] + (tau1 + tau2) (tau2^2 +
#           4 (f1 - f2)^2 \[Pi]^2 tau1^3 tau2 (1 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#           tau1^2 (1 + 12 f1^2 \[Pi]^2 tau2^2 - 24 f1 f2 \[Pi]^2 tau2^2 +
#              12 f2^2 \[Pi]^2 tau2^2) +
#           tau1 (6 tau2 + 4 (f1 - f2)^2 \[Pi]^2 tau2^3)) Sin[
#          phi1 - phi2]))/(A1 (-2 tau1 tau2 + tau2^2 +
#        tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#           4 f2^2 \[Pi]^2 tau2^2))^3 \[Sqrt](1/(
#         A1^2 tau1 tau2 (-2 tau1 tau2 + tau2^2 +
#            tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#               4 f2^2 \[Pi]^2 tau2^2))^6) (2 tau1 tau2 + tau2^2 +
#            tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#               4 f2^2 \[Pi]^2 tau2^2))^2 (8 tau1 tau2^3 + tau2^4 +
#            8 tau1^3 tau2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 -
#               8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#            tau1^4 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#               4 f2^2 \[Pi]^2 tau2^2)^2 +
#            2 tau1^2 tau2^2 (15 + 4 f1^2 \[Pi]^2 tau2^2 -
#               8 f1 f2 \[Pi]^2 tau2^2 +
#               4 f2^2 \[Pi]^2 tau2^2)) (-8 tau1 tau2^3 + tau2^4 +
#            tau1^4 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#               4 f2^2 \[Pi]^2 tau2^2)^2 +
#            2 tau1^2 tau2^2 (15 + 4 f1^2 \[Pi]^2 tau2^2 -
#               8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#            8 tau1^3 (tau2 + 4 (f1 - f2)^2 \[Pi]^2 tau2^3)))))
#
# In[59]:= (*A2\[Phi]2*)
# CA2\[Phi]2 = CorrCoef[2, 8]
#
# Out[59]= 0
#
# In[60]:= (*f1f2*)
# Cf1f2 = CorrCoef[3, 4]
#
# Out[60]= (2 (tau1 + tau2) (-2 tau1 tau2 - tau2^2 +
#       tau1^2 (-1 + 12 f1^2 \[Pi]^2 tau2^2 - 24 f1 f2 \[Pi]^2 tau2^2 +
#          12 f2^2 \[Pi]^2 tau2^2)) Cos[phi1 - phi2] -
#    4 (f1 - f2) \[Pi] tau1 tau2 (-6 tau1 tau2 - 3 tau2^2 +
#       tau1^2 (-3 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#          4 f2^2 \[Pi]^2 tau2^2)) Sin[
#      phi1 - phi2])/(A1 A2 tau1 tau2 (-2 tau1 tau2 + tau2^2 +
#      tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2))^2 Sqrt[(2 tau1 tau2 + tau2^2 +
#      tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2))^4/(
#    A1^2 A2^2 tau1^3 tau2^3 (-2 tau1 tau2 + tau2^2 +
#       tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#          4 f2^2 \[Pi]^2 tau2^2))^4)])
#
# In[61]:= (*f1\[Tau]1*)
# Cf1\[Tau]1 = CorrCoef[3, 5]
#
# Out[61]= 0
#
# In[62]:= (*f1\[Tau]2*)
# Cf1\[Tau]2 = CorrCoef[3, 6]
#
# Out[62]= -((2 tau2 (2 (f1 - f2) \[Pi] tau1 tau2 (-6 tau1 tau2 - 3 tau2^2 +
#           tau1^2 (-3 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2)) Cos[
#          phi1 - phi2] + (tau1 + tau2) (-2 tau1 tau2 - tau2^2 +
#           tau1^2 (-1 + 12 f1^2 \[Pi]^2 tau2^2 - 24 f1 f2 \[Pi]^2 tau2^2 +
#              12 f2^2 \[Pi]^2 tau2^2)) Sin[
#          phi1 - phi2]))/(A1 A2 tau1 (-2 tau1 tau2 + tau2^2 +
#        tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#           4 f2^2 \[Pi]^2 tau2^2))^2 Sqrt[(
#      tau2 (2 tau1 tau2 + tau2^2 +
#         tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#            4 f2^2 \[Pi]^2 tau2^2))^4)/(
#      A1^2 A2^2 tau1^3 (-2 tau1 tau2 + tau2^2 +
#         tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#            4 f2^2 \[Pi]^2 tau2^2))^4)]))
#
# In[63]:= (*f1\[Phi]1*)
# Cf1\[Phi]1 = CorrCoef[3, 7]
#
# Out[63]= ((2 tau1 tau2 + tau2^2 +
#      tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2)) (-8 tau1 tau2^3 + tau2^4 +
#      2 tau1^2 tau2^2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2) +
#      tau1^4 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2)^2 +
#      8 tau1^3 (tau2 + 4 (f1 - f2)^2 \[Pi]^2 tau2^3)))/(Sqrt[2]
#     A1^2 tau1^2 (-2 tau1 tau2 + tau2^2 +
#      tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2))^3 \[Sqrt](((2 tau1 tau2 + tau2^2 +
#           tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2))^3 (-8 tau1 tau2^3 + tau2^4 +
#           tau1^4 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2)^2 +
#           2 tau1^2 tau2^2 (15 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#           8 tau1^3 (tau2 +
#              4 (f1 - f2)^2 \[Pi]^2 tau2^3)))/(A1^4 tau1^4 (-2 tau1 tau2 +
#           tau2^2 + tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2))^5)))
#
# In[64]:= (*f1\[Phi]2*)
# Cf1\[Phi]2 = CorrCoef[3, 8]
#
# Out[64]= -((2 Sqrt[2]
#       tau2 ((-4 tau1 tau2^3 - tau2^4 +
#           2 tau1^2 tau2^2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#           8 (f1 - f2)^2 \[Pi]^2 tau1^5 tau2 (1 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#           4 tau1^3 (tau2 + 6 (f1 - f2)^2 \[Pi]^2 tau2^3) +
#           tau1^4 (3 + 8 f2^2 \[Pi]^2 tau2^2 + 48 f1^4 \[Pi]^4 tau2^4 -
#              192 f1^3 f2 \[Pi]^4 tau2^4 + 48 f2^4 \[Pi]^4 tau2^4 +
#              8 f1^2 (\[Pi]^2 tau2^2 + 36 f2^2 \[Pi]^4 tau2^4) -
#              16 f1 (f2 \[Pi]^2 tau2^2 + 12 f2^3 \[Pi]^4 tau2^4))) Cos[
#          phi1 - phi2] -
#        2 (f1 - f2) \[Pi] tau1 (-10 tau1 tau2^3 - 3 tau2^4 +
#           tau1^3 (2 tau2 - 8 (f1 - f2)^2 \[Pi]^2 tau2^3) -
#           4 tau1^2 (tau2^2 + 2 (f1 - f2)^2 \[Pi]^2 tau2^4) +
#           tau1^4 (-1 + 16 f1^4 \[Pi]^4 tau2^4 - 64 f1^3 f2 \[Pi]^4 tau2^4 +
#              96 f1^2 f2^2 \[Pi]^4 tau2^4 - 64 f1 f2^3 \[Pi]^4 tau2^4 +
#              16 f2^4 \[Pi]^4 tau2^4)) Sin[
#          phi1 - phi2]))/(A1 A2 tau1 (-2 tau1 tau2 + tau2^2 +
#        tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#           4 f2^2 \[Pi]^2 tau2^2))^3 \[Sqrt](((2 tau1 tau2 + tau2^2 +
#             tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#                4 f2^2 \[Pi]^2 tau2^2))^3 (8 tau1 tau2^3 + tau2^4 +
#             8 tau1^3 tau2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 -
#                8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#             tau1^4 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#                4 f2^2 \[Pi]^2 tau2^2)^2 +
#             2 tau1^2 tau2^2 (15 + 4 f1^2 \[Pi]^2 tau2^2 -
#                8 f1 f2 \[Pi]^2 tau2^2 +
#                4 f2^2 \[Pi]^2 tau2^2)))/(A1^2 A2^2 tau1^3 tau2 (-2 tau1 tau2 +
#              tau2^2 +
#             tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#                4 f2^2 \[Pi]^2 tau2^2))^5))))
#
# In[65]:= (*f2\[Tau]1*)
# Cf2\[Tau]1 = CorrCoef[4, 5]
#
# Out[65]= (2 tau1 (2 (f1 - f2) \[Pi] tau1 tau2 (-6 tau1 tau2 - 3 tau2^2 +
#         tau1^2 (-3 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#            4 f2^2 \[Pi]^2 tau2^2)) Cos[
#        phi1 - phi2] + (tau1 + tau2) (-2 tau1 tau2 - tau2^2 +
#         tau1^2 (-1 + 12 f1^2 \[Pi]^2 tau2^2 - 24 f1 f2 \[Pi]^2 tau2^2 +
#            12 f2^2 \[Pi]^2 tau2^2)) Sin[
#        phi1 - phi2]))/(A1 A2 tau2 (-2 tau1 tau2 + tau2^2 +
#      tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2))^2 Sqrt[(
#    tau1 (2 tau1 tau2 + tau2^2 +
#       tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#          4 f2^2 \[Pi]^2 tau2^2))^4)/(
#    A1^2 A2^2 tau2^3 (-2 tau1 tau2 + tau2^2 +
#       tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#          4 f2^2 \[Pi]^2 tau2^2))^4)])
#
# In[66]:= (*f2\[Tau]2*)
# Cf2\[Tau]2 = CorrCoef[4, 6]
#
# Out[66]= 0
#
# In[67]:= (*f2\[Phi]1*)
# Cf2\[Phi]1 = CorrCoef[4, 7]
#
# Out[67]= -((2 Sqrt[2]
#       tau1 ((3 tau2^4 +
#           2 tau1^2 tau2^2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#           4 tau1 (tau2^3 + 2 (f1 - f2)^2 \[Pi]^2 tau2^5) +
#           4 tau1^3 tau2 (-1 + 6 f2^2 \[Pi]^2 tau2^2 + 8 f1^4 \[Pi]^4 tau2^4 -
#              32 f1^3 f2 \[Pi]^4 tau2^4 + 8 f2^4 \[Pi]^4 tau2^4 -
#              4 f1 f2 \[Pi]^2 tau2^2 (3 + 8 f2^2 \[Pi]^2 tau2^2) +
#              6 f1^2 (\[Pi]^2 tau2^2 + 8 f2^2 \[Pi]^4 tau2^4)) +
#           tau1^4 (-1 + 8 f2^2 \[Pi]^2 tau2^2 + 48 f1^4 \[Pi]^4 tau2^4 -
#              192 f1^3 f2 \[Pi]^4 tau2^4 + 48 f2^4 \[Pi]^4 tau2^4 +
#              8 f1^2 (\[Pi]^2 tau2^2 + 36 f2^2 \[Pi]^4 tau2^4) -
#              16 f1 (f2 \[Pi]^2 tau2^2 + 12 f2^3 \[Pi]^4 tau2^4))) Cos[
#          phi1 - phi2] -
#        2 (f1 - f2) \[Pi] tau2 (-4 tau1^2 tau2^2 + 2 tau1 tau2^3 - tau2^4 -
#           2 tau1^3 tau2 (5 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2) +
#           tau1^4 (-3 - 8 f2^2 \[Pi]^2 tau2^2 + 16 f1^4 \[Pi]^4 tau2^4 -
#              64 f1^3 f2 \[Pi]^4 tau2^4 + 16 f2^4 \[Pi]^4 tau2^4 +
#              f1^2 (-8 \[Pi]^2 tau2^2 + 96 f2^2 \[Pi]^4 tau2^4) +
#              f1 (16 f2 \[Pi]^2 tau2^2 - 64 f2^3 \[Pi]^4 tau2^4))) Sin[
#          phi1 - phi2]))/(A1 A2 tau2 (-2 tau1 tau2 + tau2^2 +
#        tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#           4 f2^2 \[Pi]^2 tau2^2))^3 \[Sqrt](((2 tau1 tau2 + tau2^2 +
#             tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#                4 f2^2 \[Pi]^2 tau2^2))^3 (-8 tau1 tau2^3 + tau2^4 +
#             tau1^4 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#                4 f2^2 \[Pi]^2 tau2^2)^2 +
#             2 tau1^2 tau2^2 (15 + 4 f1^2 \[Pi]^2 tau2^2 -
#                8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#             8 tau1^3 (tau2 +
#                4 (f1 - f2)^2 \[Pi]^2 tau2^3)))/(A1^2 A2^2 tau1 tau2^\
# 3 (-2 tau1 tau2 + tau2^2 +
#             tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#                4 f2^2 \[Pi]^2 tau2^2))^5))))
#
# In[68]:= (*f2\[Phi]2*)
# Cf2\[Phi]2 = CorrCoef[4, 8]
#
# Out[68]= ((2 tau1 tau2 + tau2^2 +
#      tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2)) (8 tau1 tau2^3 + tau2^4 +
#      8 tau1^3 tau2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2) +
#      2 tau1^2 tau2^2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2) +
#      tau1^4 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2)^2))/(Sqrt[2]
#     A2^2 tau2^2 (-2 tau1 tau2 + tau2^2 +
#      tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2))^3 \[Sqrt](((2 tau1 tau2 + tau2^2 +
#           tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2))^3 (8 tau1 tau2^3 + tau2^4 +
#           8 tau1^3 tau2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#           tau1^4 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2)^2 +
#           2 tau1^2 tau2^2 (15 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2)))/(A2^4 tau2^4 (-2 tau1 tau2 + tau2^2 +
#           tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2))^5)))
#
# In[69]:= (*\[Tau]1\[Tau]2*)
# C\[Tau]1\[Tau]2 = CorrCoef[5, 6]
#
# Out[69]= -((2 tau1 tau2 (-((tau1 + tau2) (-2 tau1 tau2 - tau2^2 +
#             tau1^2 (-1 + 12 f1^2 \[Pi]^2 tau2^2 - 24 f1 f2 \[Pi]^2 tau2^2 +
#                12 f2^2 \[Pi]^2 tau2^2)) Cos[phi1 - phi2]) +
#        2 (f1 - f2) \[Pi] tau1 tau2 (-6 tau1 tau2 - 3 tau2^2 +
#           tau1^2 (-3 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2)) Sin[phi1 - phi2]))/(A1 A2 (-2 tau1 tau2 +
#         tau2^2 +
#        tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#           4 f2^2 \[Pi]^2 tau2^2))^2 Sqrt[(
#      tau1 tau2 (2 tau1 tau2 + tau2^2 +
#         tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#            4 f2^2 \[Pi]^2 tau2^2))^4)/(
#      A1^2 A2^2 (-2 tau1 tau2 + tau2^2 +
#         tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#            4 f2^2 \[Pi]^2 tau2^2))^4)]))
#
# In[48]:= (*\[Tau]1\[Phi]1*)
# C\[Tau]1\[Phi]1 = CorrCoef[5, 7]
#
# Out[48]= -((16 Sqrt[
#      2] (f1 - f2) \[Pi] tau1^2 tau2^3 (2 tau1 tau2 + tau2^2 +
#        tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#           4 f2^2 \[Pi]^2 tau2^2)))/(A1^2 (-2 tau1 tau2 + tau2^2 +
#        tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#           4 f2^2 \[Pi]^2 tau2^2))^3 \[Sqrt](((2 tau1 tau2 + tau2^2 +
#             tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#                4 f2^2 \[Pi]^2 tau2^2))^3 (-8 tau1 tau2^3 + tau2^4 +
#             tau1^4 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#                4 f2^2 \[Pi]^2 tau2^2)^2 +
#             2 tau1^2 tau2^2 (15 + 4 f1^2 \[Pi]^2 tau2^2 -
#                8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#             8 tau1^3 (tau2 +
#                4 (f1 - f2)^2 \[Pi]^2 tau2^3)))/(A1^4 (-2 tau1 tau2 + tau2^2 +
#             tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#                4 f2^2 \[Pi]^2 tau2^2))^5))))
#
# In[49]:= (*\[Tau]1\[Phi]2*)
# C\[Tau]1\[Phi]2 = CorrCoef[5, 8]
#
# Out[49]= -((2 Sqrt[2]
#       tau1 tau2 (2 (f1 - f2) \[Pi] tau1 (-10 tau1 tau2^3 - 3 tau2^4 +
#           tau1^3 (2 tau2 - 8 (f1 - f2)^2 \[Pi]^2 tau2^3) -
#           4 tau1^2 (tau2^2 + 2 (f1 - f2)^2 \[Pi]^2 tau2^4) +
#           tau1^4 (-1 + 16 f1^4 \[Pi]^4 tau2^4 - 64 f1^3 f2 \[Pi]^4 tau2^4 +
#              96 f1^2 f2^2 \[Pi]^4 tau2^4 - 64 f1 f2^3 \[Pi]^4 tau2^4 +
#              16 f2^4 \[Pi]^4 tau2^4)) Cos[
#          phi1 - phi2] + (-4 tau1 tau2^3 - tau2^4 +
#           2 tau1^2 tau2^2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#           8 (f1 - f2)^2 \[Pi]^2 tau1^5 tau2 (1 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#           4 tau1^3 (tau2 + 6 (f1 - f2)^2 \[Pi]^2 tau2^3) +
#           tau1^4 (3 + 8 f2^2 \[Pi]^2 tau2^2 + 48 f1^4 \[Pi]^4 tau2^4 -
#              192 f1^3 f2 \[Pi]^4 tau2^4 + 48 f2^4 \[Pi]^4 tau2^4 +
#              8 f1^2 (\[Pi]^2 tau2^2 + 36 f2^2 \[Pi]^4 tau2^4) -
#              16 f1 (f2 \[Pi]^2 tau2^2 + 12 f2^3 \[Pi]^4 tau2^4))) Sin[
#          phi1 - phi2]))/(A1 A2 (-2 tau1 tau2 + tau2^2 +
#        tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#           4 f2^2 \[Pi]^2 tau2^2))^3 \[Sqrt]((tau1 (2 tau1 tau2 + tau2^2 +
#             tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#                4 f2^2 \[Pi]^2 tau2^2))^3 (8 tau1 tau2^3 + tau2^4 +
#             8 tau1^3 tau2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 -
#                8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#             tau1^4 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#                4 f2^2 \[Pi]^2 tau2^2)^2 +
#             2 tau1^2 tau2^2 (15 + 4 f1^2 \[Pi]^2 tau2^2 -
#                8 f1 f2 \[Pi]^2 tau2^2 +
#                4 f2^2 \[Pi]^2 tau2^2)))/(A1^2 A2^2 tau2 (-2 tau1 tau2 +
#             tau2^2 + tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 -
#                8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2))^5))))
#
# In[50]:= (*\[Tau]2\[Phi]1*)
# C\[Tau]2\[Phi]1 = CorrCoef[6, 7]
#
# Out[50]= (2 Sqrt[2]
#     tau1 tau2 (2 (f1 - f2) \[Pi] tau2 (-4 tau1^2 tau2^2 + 2 tau1 tau2^3 -
#         tau2^4 - 2 tau1^3 tau2 (5 + 4 f1^2 \[Pi]^2 tau2^2 -
#            8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#         tau1^4 (-3 - 8 f2^2 \[Pi]^2 tau2^2 + 16 f1^4 \[Pi]^4 tau2^4 -
#            64 f1^3 f2 \[Pi]^4 tau2^4 + 16 f2^4 \[Pi]^4 tau2^4 +
#            f1^2 (-8 \[Pi]^2 tau2^2 + 96 f2^2 \[Pi]^4 tau2^4) +
#            f1 (16 f2 \[Pi]^2 tau2^2 - 64 f2^3 \[Pi]^4 tau2^4))) Cos[
#        phi1 - phi2] + (3 tau2^4 +
#         2 tau1^2 tau2^2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 -
#            8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#         4 tau1 (tau2^3 + 2 (f1 - f2)^2 \[Pi]^2 tau2^5) +
#         4 tau1^3 tau2 (-1 + 6 f2^2 \[Pi]^2 tau2^2 + 8 f1^4 \[Pi]^4 tau2^4 -
#            32 f1^3 f2 \[Pi]^4 tau2^4 + 8 f2^4 \[Pi]^4 tau2^4 -
#            4 f1 f2 \[Pi]^2 tau2^2 (3 + 8 f2^2 \[Pi]^2 tau2^2) +
#            6 f1^2 (\[Pi]^2 tau2^2 + 8 f2^2 \[Pi]^4 tau2^4)) +
#         tau1^4 (-1 + 8 f2^2 \[Pi]^2 tau2^2 + 48 f1^4 \[Pi]^4 tau2^4 -
#            192 f1^3 f2 \[Pi]^4 tau2^4 + 48 f2^4 \[Pi]^4 tau2^4 +
#            8 f1^2 (\[Pi]^2 tau2^2 + 36 f2^2 \[Pi]^4 tau2^4) -
#            16 f1 (f2 \[Pi]^2 tau2^2 + 12 f2^3 \[Pi]^4 tau2^4))) Sin[
#        phi1 - phi2]))/(A1 A2 (-2 tau1 tau2 + tau2^2 +
#      tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2))^3 \[Sqrt]((tau2 (2 tau1 tau2 + tau2^2 +
#           tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2))^3 (-8 tau1 tau2^3 + tau2^4 +
#           tau1^4 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2)^2 +
#           2 tau1^2 tau2^2 (15 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#           8 tau1^3 (tau2 +
#              4 (f1 - f2)^2 \[Pi]^2 tau2^3)))/(A1^2 A2^2 tau1 (-2 tau1 tau2 +
#           tau2^2 + tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2))^5)))
#
# In[51]:= (*\[Tau]2\[Phi]2*)
# C\[Tau]2\[Phi]2 = CorrCoef[6, 8]
#
# Out[51]= (16 Sqrt[2] (f1 - f2) \[Pi] tau1^3 tau2^2 (2 tau1 tau2 + tau2^2 +
#      tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2)))/(A2^2 (-2 tau1 tau2 + tau2^2 +
#      tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2))^3 \[Sqrt](((2 tau1 tau2 + tau2^2 +
#           tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2))^3 (8 tau1 tau2^3 + tau2^4 +
#           8 tau1^3 tau2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#           tau1^4 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2)^2 +
#           2 tau1^2 tau2^2 (15 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2)))/(A2^4 (-2 tau1 tau2 + tau2^2 +
#           tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2))^5)))
#
# In[44]:= (*\[Phi]1\[Phi]2*)
# C\[Phi]1\[Phi]2 = CorrCoef[7, 8]
#
# Out[44]= (8 tau1 tau2 ((tau1 + tau2) (tau2^2 +
#         4 (f1 - f2)^2 \[Pi]^2 tau1^3 tau2 (1 + 4 f1^2 \[Pi]^2 tau2^2 -
#            8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#         tau1^2 (1 + 12 f1^2 \[Pi]^2 tau2^2 - 24 f1 f2 \[Pi]^2 tau2^2 +
#            12 f2^2 \[Pi]^2 tau2^2) +
#         tau1 (6 tau2 + 4 (f1 - f2)^2 \[Pi]^2 tau2^3)) Cos[
#        phi1 - phi2] - (f1 - f2) \[Pi] (6 tau1^2 tau2^2 - 2 tau1 tau2^3 -
#         tau2^4 + 2 tau1^3 tau2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 -
#            8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#         tau1^4 (-1 + 16 f1^4 \[Pi]^4 tau2^4 - 64 f1^3 f2 \[Pi]^4 tau2^4 +
#            96 f1^2 f2^2 \[Pi]^4 tau2^4 - 64 f1 f2^3 \[Pi]^4 tau2^4 +
#            16 f2^4 \[Pi]^4 tau2^4)) Sin[phi1 - phi2]))/(A1 A2 (-2 tau1 tau2 +
#      tau2^2 + tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#         4 f2^2 \[Pi]^2 tau2^2))^3 \[Sqrt](((2 tau1 tau2 + tau2^2 +
#           tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2))^2 (8 tau1 tau2^3 + tau2^4 +
#           8 tau1^3 tau2 (-1 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#           tau1^4 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2)^2 +
#           2 tau1^2 tau2^2 (15 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2)) (-8 tau1 tau2^3 + tau2^4 +
#           tau1^4 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2)^2 +
#           2 tau1^2 tau2^2 (15 + 4 f1^2 \[Pi]^2 tau2^2 -
#              8 f1 f2 \[Pi]^2 tau2^2 + 4 f2^2 \[Pi]^2 tau2^2) +
#           8 tau1^3 (tau2 +
#              4 (f1 - f2)^2 \[Pi]^2 tau2^3)))/(A1^2 A2^\
# 2 tau1 tau2 (-2 tau1 tau2 + tau2^2 +
#           tau1^2 (1 + 4 f1^2 \[Pi]^2 tau2^2 - 8 f1 f2 \[Pi]^2 tau2^2 +
#              4 f2^2 \[Pi]^2 tau2^2))^6)))

# %%
from bilby.gw.detector.psd import PowerSpectralDensity
import matplotlib.pyplot as plt
import numpy as np

asd_file_L1 = 'asd_files/aLIGO_O4_high_asd.txt'
asd_file_V1 = 'asd_files/AdV_asd.txt'
asd_file_H1 = 'asd_files/aLIGO_O4_high_asd.txt'

psd_L1 = PowerSpectralDensity(asd_file = asd_file_L1)
psd_H1 = PowerSpectralDensity(asd_file = asd_file_H1)
psd_V1 = PowerSpectralDensity(asd_file = asd_file_V1)

asd_array_L1 = psd_L1.asd_array
asd_array_H1 = psd_H1.asd_array
asd_array_V1 = psd_V1.asd_array

psd_array_L1 = psd_L1.psd_array
psd_array_H1 = psd_H1.psd_array
psd_array_V1 = psd_V1.psd_array

plt.figure(figsize=(10, 6))
plt.plot(psd_L1.frequency_array, asd_array_L1, label='L1 ASD', color='blue')
plt.plot(psd_H1.frequency_array, asd_array_H1, label='H1 ASD', color='orange')
plt.plot(psd_V1.frequency_array, asd_array_V1, label='V1 ASD', color='green')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Frequency (Hz)')
plt.ylabel('ASD')
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(psd_L1.frequency_array, psd_array_L1, label='L1 ASD', color='blue')
plt.plot(psd_H1.frequency_array, psd_array_H1, label='H1 ASD', color='orange')
plt.plot(psd_V1.frequency_array, psd_array_V1, label='V1 ASD', color='green')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Frequency (Hz)')
plt.ylabel('PSD')
plt.legend()
plt.grid()
plt.show()

max_f = 250
min_f = 150
frequency_band_L1 = (psd_L1.frequency_array > min_f) & (psd_L1.frequency_array < max_f)
frequency_band_H1 = (psd_H1.frequency_array > min_f) & (psd_H1.frequency_array < max_f)
frequency_band_V1 = (psd_V1.frequency_array > min_f) & (psd_V1.frequency_array < max_f)

in_band_psd_L1 = psd_array_L1[frequency_band_L1]
in_band_psd_H1 = psd_array_H1[frequency_band_H1]
in_band_psd_V1 = psd_array_V1[frequency_band_V1]

median_in_band_psd_L1 = np.median(in_band_psd_L1)
median_in_band_psd_H1 = np.median(in_band_psd_H1)
median_in_band_psd_V1 = np.median(in_band_psd_V1)

print(f"L1 median PSD between {min_f}Hz and {max_f}Hz: {median_in_band_psd_L1}")
print(f"H1 median PSD between {min_f}Hz and {max_f}Hz: {median_in_band_psd_H1}")
print(f"V1 median PSD between {min_f}Hz and {max_f}Hz: {median_in_band_psd_V1}")
# Out:
# L1 median PSD between 150Hz and 250Hz: 1.0428843794225e-47
# H1 median PSD between 150Hz and 250Hz: 1.0428843794225e-47
# V1 median PSD between 150Hz and 250Hz: 1.5216689401916227e-47

# %%
from __future__ import division, print_function
import bilby
from gwpy.timeseries import TimeSeries
import math
from bilby.gw.conversion import component_masses_to_chirp_mass, component_masses_to_symmetric_mass_ratio, luminosity_distance_to_redshift, chirp_mass_and_mass_ratio_to_component_masses
from bilby.core import utils
import numpy as np
from gwosc import datasets
from astropy import constants as const
import sys
import argparse
import configparser
import os
import errno
import json
import datetime
import scipy.signal.windows as windows
import matplotlib.pyplot as plt
from bilby.core.utils import infft
from pesummary.io import read
import seaborn as sns
from scipy.stats import norm

"""get current time"""
start = datetime.datetime.now()

"""constants"""
Mo = const.M_sun.value #solar mass [kg]
G = const.G.value #Newton constant [m^3 kg^-1 s^2]
c = const.c.value #light speed [m s^-1]
pc = const.pc.value #1pc [m]

def sigma_A1(f1: float, f2: float, tau1: float, tau2: float) -> float:
    
    f_diff_sq_pi_sq = (f1 - f2)**2 * np.pi**2
    term_in_paren = 1 + 4 * f_diff_sq_pi_sq * tau2**2
    
    common_term1 = 2 * tau1 * tau2 + tau2**2 + tau1**2 * term_in_paren
    common_term2 = -2 * tau1 * tau2 + tau2**2 + tau1**2 * term_in_paren

    numerator_sum = (
        -8 * tau1 * tau2**3 + tau2**4 + tau1**4 * term_in_paren**2
        + 2 * tau1**2 * tau2**2 * (15 + 4 * f_diff_sq_pi_sq * tau2**2)
        + 8 * tau1**3 * (tau2 + 4 * f_diff_sq_pi_sq * tau2**3)
    )

    inside_sqrt = -(common_term1 / (tau1 * common_term2**3)) * numerator_sum
    
    return np.sqrt(10) * np.sqrt(inside_sqrt)

def sigma_A2(f1: float, f2: float, tau1: float, tau2: float) -> float:

    f_diff_sq_pi_sq = (f1 - f2)**2 * np.pi**2
    term_in_paren = 1 + 4 * f_diff_sq_pi_sq * tau2**2
    
    common_term1 = 2 * tau1 * tau2 + tau2**2 + tau1**2 * term_in_paren
    common_term2 = -2 * tau1 * tau2 + tau2**2 + tau1**2 * term_in_paren

    numerator_sum = (
        8 * tau1 * tau2**3 + tau2**4
        + 8 * tau1**3 * tau2 * (-1 + 4 * f_diff_sq_pi_sq * tau2**2)
        + tau1**4 * term_in_paren**2
        + 2 * tau1**2 * tau2**2 * (15 + 4 * f_diff_sq_pi_sq * tau2**2)
    )
    
    inside_sqrt = -(common_term1 / (tau2 * common_term2**3)) * numerator_sum

    return np.sqrt(10) * np.sqrt(inside_sqrt)

def sigma_f1(A1: float, f1: float, f2: float, tau1: float, tau2: float) -> float:

    term_in_paren = 1 + 4 * (f1 - f2)**2 * np.pi**2 * tau2**2
    
    common_term1 = 2 * tau1 * tau2 + tau2**2 + tau1**2 * term_in_paren
    common_term2 = -2 * tau1 * tau2 + tau2**2 + tau1**2 * term_in_paren
    
    numerator = np.sqrt(5) * common_term1
    denominator = A1 * np.pi * (-tau1)**1.5 * common_term2
    
    return numerator / denominator

def sigma_f2(A2: float, f1: float, f2: float, tau1: float, tau2: float) -> float:
   
    term_in_paren = 1 + 4 * (f1 - f2)**2 * np.pi**2 * tau2**2
    
    common_term1 = 2 * tau1 * tau2 + tau2**2 + tau1**2 * term_in_paren
    common_term2 = -2 * tau1 * tau2 + tau2**2 + tau1**2 * term_in_paren

    numerator = np.sqrt(5) * common_term1
    denominator = A2 * np.pi * (-tau2)**1.5 * common_term2
    
    return numerator / denominator

def sigma_tau1(A1: float, f1: float, f2: float, tau1: float, tau2: float) -> float:

    term_in_paren = 1 + 4 * (f1 - f2)**2 * np.pi**2 * tau2**2
    
    common_term1 = 2 * tau1 * tau2 + tau2**2 + tau1**2 * term_in_paren
    common_term2 = -2 * tau1 * tau2 + tau2**2 + tau1**2 * term_in_paren
    
    numerator = 2 * np.sqrt(5) * np.sqrt(-tau1) * common_term1
    denominator = A1 * common_term2
    
    return numerator / denominator

def sigma_tau2(A2: float, f1: float, f2: float, tau1: float, tau2: float) -> float:

    term_in_paren = 1 + 4 * (f1 - f2)**2 * np.pi**2 * tau2**2
    
    common_term1 = 2 * tau1 * tau2 + tau2**2 + tau1**2 * term_in_paren
    common_term2 = -2 * tau1 * tau2 + tau2**2 + tau1**2 * term_in_paren

    numerator = 2 * np.sqrt(5) * np.sqrt(-tau2) * common_term1
    denominator = A2 * common_term2
    
    return numerator / denominator

def sigma_phi1(A1: float, f1: float, f2: float, tau1: float, tau2: float) -> float:

    f_diff_sq_pi_sq = (f1 - f2)**2 * np.pi**2
    term_in_paren = 1 + 4 * f_diff_sq_pi_sq * tau2**2
    
    common_term1 = 2 * tau1 * tau2 + tau2**2 + tau1**2 * term_in_paren
    common_term2 = -2 * tau1 * tau2 + tau2**2 + tau1**2 * term_in_paren

    numerator_sum = (
        -8 * tau1 * tau2**3 + tau2**4 + tau1**4 * term_in_paren**2
        + 2 * tau1**2 * tau2**2 * (15 + 4 * f_diff_sq_pi_sq * tau2**2)
        + 8 * tau1**3 * (tau2 + 4 * f_diff_sq_pi_sq * tau2**3)
    )

    inside_sqrt = -(common_term1 / (tau1 * common_term2**3)) * numerator_sum
    
    return np.sqrt(10) * np.sqrt(inside_sqrt) / A1

def sigma_phi2(A2: float, f1: float, f2: float, tau1: float, tau2: float) -> float:
    
    f_diff_sq_pi_sq = (f1 - f2)**2 * np.pi**2
    term_in_paren = 1 + 4 * f_diff_sq_pi_sq * tau2**2
    
    common_term1 = 2 * tau1 * tau2 + tau2**2 + tau1**2 * term_in_paren
    common_term2 = -2 * tau1 * tau2 + tau2**2 + tau1**2 * term_in_paren

    numerator_sum = (
        8 * tau1 * tau2**3 + tau2**4
        + 8 * tau1**3 * tau2 * (-1 + 4 * f_diff_sq_pi_sq * tau2**2)
        + tau1**4 * term_in_paren**2
        + 2 * tau1**2 * tau2**2 * (15 + 4 * f_diff_sq_pi_sq * tau2**2)
    )
    
    inside_sqrt = -(common_term1 / (tau2 * common_term2**3)) * numerator_sum

    return np.sqrt(10) * np.sqrt(inside_sqrt) / A2

def calculate_analitical_iFIM_of_DSparam(config_file_path, inject_as_damped_sinusoid=True):
    """read config file"""
    config_path = config_file_path
    config_ini = configparser.ConfigParser()
    config_ini.read(config_path)

    config_setting = config_ini['setting']
    config_injection = config_ini['injection_parameters']
    config_wf_args = config_ini['waveform_arguments']
    config_others = config_ini['other_parameters']
    
    mode_number = config_setting['mode_number']
    if mode_number=='one_mode':
        one_mode=True
    bilby.core.utils.logger.info('mode_number : '+mode_number)

    """set injection parameters and waveform generator"""
    A = float(config_injection['A']) * 1e-20  # Convert to strain unit
    alpha = float(config_injection['alpha'])
    w1 = (2 * np.pi * float(config_injection['f1']) + 1j / float(config_injection['tau1']))
    w2 = (2 * np.pi * float(config_injection['f2']) + 1j / float(config_injection['tau2']))
    delta_w = w2 - w1
    A1_complex = A / delta_w
    A1 = np.abs(A1_complex) / 1e-20
    phi1_from_amp = np.angle(A1_complex)
    phi1 = float(config_injection['phi1']) + phi1_from_amp
    A2_complex = - A * (1 + alpha * delta_w) / delta_w
    A2 = np.abs(A2_complex) / 1e-20
    phi2_from_amp = np.angle(A2_complex)
    phi2 = float(config_injection['phi2']) + phi2_from_amp
    bilby.core.utils.logger.info('A1 : {}'.format(A1))
    bilby.core.utils.logger.info('A2 : {}'.format(A2))
    bilby.core.utils.logger.info('alpha : {}'.format(alpha))
    bilby.core.utils.logger.info('w1 : {}'.format(w1))
    bilby.core.utils.logger.info('w2 : {}'.format(w2))
    bilby.core.utils.logger.info('delta_w : {}'.format(delta_w))
    bilby.core.utils.logger.info('delta_w * alpha : {}'.format(delta_w * alpha))
    bilby.core.utils.logger.info('|delta_w| / |w1| : {}'.format(np.abs(delta_w) / np.abs(w1)))
    bilby.core.utils.logger.info('phi1 : {}'.format(phi1))
    bilby.core.utils.logger.info('phi2 : {}'.format(phi2))
    injection_parameters = dict(
                                A1 = A1 * 1e-20,
                                A2 = A2 * 1e-20,
                                f1 = float(config_injection['f1']),
                                tau1 = float(config_injection['tau1']),
                                f2 = float(config_injection['f2']),
                                tau2 = float(config_injection['tau2']),
                                phi1 = phi1,
                                phi2 = phi2,
                                ra = float(config_injection['ra']),
                                dec = float(config_injection['dec']),
                                psi = float(config_injection['psi']),
                                geocent_time = float(config_injection['geocent_time']),
                                )

    detectors = ['L1', 'H1', 'V1']
    psd_dict = {
        'L1': median_in_band_psd_L1,
        'H1': median_in_band_psd_H1,
        'V1': median_in_band_psd_V1
    }

    _sigma_A1_square = 0
    _sigma_A2_square = 0
    _sigma_f1_square = 0
    _sigma_f2_square = 0
    _sigma_tau1_square = 0
    _sigma_tau2_square = 0
    _sigma_phi1_square = 0
    _sigma_phi2_square = 0
    for det in detectors:
        _sigma_A1_square += sigma_A1(injection_parameters['f1'], injection_parameters['f2'], injection_parameters['tau1'], injection_parameters['tau2'])**2 * psd_dict[det]
        _sigma_A2_square += sigma_A2(injection_parameters['f1'], injection_parameters['f2'], injection_parameters['tau1'], injection_parameters['tau2'])**2 * psd_dict[det]
        _sigma_f1_square += sigma_f1(injection_parameters['A1'], injection_parameters['f1'], injection_parameters['f2'], injection_parameters['tau1'], injection_parameters['tau2'])**2 * psd_dict[det]
        _sigma_f2_square += sigma_f2(injection_parameters['A2'], injection_parameters['f1'], injection_parameters['f2'], injection_parameters['tau1'], injection_parameters['tau2'])**2 * psd_dict[det]
        _sigma_tau1_square += sigma_tau1(injection_parameters['A1'], injection_parameters['f1'], injection_parameters['f2'], injection_parameters['tau1'], injection_parameters['tau2'])**2 * psd_dict[det]
        _sigma_tau2_square += sigma_tau2(injection_parameters['A2'], injection_parameters['f1'], injection_parameters['f2'], injection_parameters['tau1'], injection_parameters['tau2'])**2 * psd_dict[det]
        _sigma_phi1_square += sigma_phi1(injection_parameters['A1'], injection_parameters['f1'], injection_parameters['f2'], injection_parameters['tau1'], injection_parameters['tau2'])**2 * psd_dict[det]
        _sigma_phi2_square += sigma_phi2(injection_parameters['A2'], injection_parameters['f1'], injection_parameters['f2'], injection_parameters['tau1'], injection_parameters['tau2'])**2 * psd_dict[det]

    _sigma_A1 = np.sqrt(_sigma_A1_square)
    _sigma_A2 = np.sqrt(_sigma_A2_square)
    _sigma_f1 = np.sqrt(_sigma_f1_square)
    _sigma_f2 = np.sqrt(_sigma_f2_square)
    _sigma_tau1 = np.sqrt(_sigma_tau1_square)
    _sigma_tau2 = np.sqrt(_sigma_tau2_square)
    _sigma_phi1 = np.sqrt(_sigma_phi1_square)
    _sigma_phi2 = np.sqrt(_sigma_phi2_square)

    return _sigma_A1, _sigma_A2, _sigma_f1, _sigma_f2, _sigma_tau1, _sigma_tau2, _sigma_phi1, _sigma_phi2

def calculate_analitical_iFIM_of_DSparam(config_file_path, inject_as_damped_sinusoid=True):
    """read config file"""
    config_path = config_file_path
    config_ini = configparser.ConfigParser()
    config_ini.read(config_path)

    config_setting = config_ini['setting']
    config_injection = config_ini['injection_parameters']
    config_wf_args = config_ini['waveform_arguments']
    config_others = config_ini['other_parameters']
    
    mode_number = config_setting['mode_number']
    if mode_number=='one_mode':
        one_mode=True
    bilby.core.utils.logger.info('mode_number : '+mode_number)

    """set injection parameters and waveform generator"""
    A = float(config_injection['A']) * 1e-20  # Convert to strain unit
    alpha = float(config_injection['alpha'])
    w1 = (2 * np.pi * float(config_injection['f1']) + 1j / float(config_injection['tau1']))
    w2 = (2 * np.pi * float(config_injection['f2']) + 1j / float(config_injection['tau2']))
    delta_w = w2 - w1
    A1_complex = A / delta_w
    A1 = np.abs(A1_complex) / 1e-20
    phi1_from_amp = np.angle(A1_complex)
    phi1 = float(config_injection['phi1']) + phi1_from_amp
    A2_complex = - A * (1 + alpha * delta_w) / delta_w
    A2 = np.abs(A2_complex) / 1e-20
    phi2_from_amp = np.angle(A2_complex)
    phi2 = float(config_injection['phi2']) + phi2_from_amp
    bilby.core.utils.logger.info('A1 : {}'.format(A1))
    bilby.core.utils.logger.info('A2 : {}'.format(A2))
    bilby.core.utils.logger.info('alpha : {}'.format(alpha))
    bilby.core.utils.logger.info('w1 : {}'.format(w1))
    bilby.core.utils.logger.info('w2 : {}'.format(w2))
    bilby.core.utils.logger.info('delta_w : {}'.format(delta_w))
    bilby.core.utils.logger.info('delta_w * alpha : {}'.format(delta_w * alpha))
    bilby.core.utils.logger.info('|delta_w| / |w1| : {}'.format(np.abs(delta_w) / np.abs(w1)))
    bilby.core.utils.logger.info('phi1 : {}'.format(phi1))
    bilby.core.utils.logger.info('phi2 : {}'.format(phi2))
    injection_parameters = dict(
                                A1 = A1 * 1e-20,
                                A2 = A2 * 1e-20,
                                f1 = float(config_injection['f1']),
                                tau1 = float(config_injection['tau1']),
                                f2 = float(config_injection['f2']),
                                tau2 = float(config_injection['tau2']),
                                phi1 = phi1,
                                phi2 = phi2,
                                ra = float(config_injection['ra']),
                                dec = float(config_injection['dec']),
                                psi = float(config_injection['psi']),
                                geocent_time = float(config_injection['geocent_time']),
                                )

    detectors = ['L1', 'H1', 'V1']
    psd_dict = {
        'L1': median_in_band_psd_L1,
        'H1': median_in_band_psd_H1,
        'V1': median_in_band_psd_V1
    }

    _sigma_A1_square = 0
    _sigma_A2_square = 0
    _sigma_f1_square = 0
    _sigma_f2_square = 0
    _sigma_tau1_square = 0
    _sigma_tau2_square = 0
    _sigma_phi1_square = 0
    _sigma_phi2_square = 0
    for det in detectors:
        _sigma_A1_square += sigma_A1(injection_parameters['f1'], injection_parameters['f2'], injection_parameters['tau1'], injection_parameters['tau2'])**2 * psd_dict[det]
        _sigma_A2_square += sigma_A2(injection_parameters['f1'], injection_parameters['f2'], injection_parameters['tau1'], injection_parameters['tau2'])**2 * psd_dict[det]
        _sigma_f1_square += sigma_f1(injection_parameters['A1'], injection_parameters['f1'], injection_parameters['f2'], injection_parameters['tau1'], injection_parameters['tau2'])**2 * psd_dict[det]
        _sigma_f2_square += sigma_f2(injection_parameters['A2'], injection_parameters['f1'], injection_parameters['f2'], injection_parameters['tau1'], injection_parameters['tau2'])**2 * psd_dict[det]
        _sigma_tau1_square += sigma_tau1(injection_parameters['A1'], injection_parameters['f1'], injection_parameters['f2'], injection_parameters['tau1'], injection_parameters['tau2'])**2 * psd_dict[det]
        _sigma_tau2_square += sigma_tau2(injection_parameters['A2'], injection_parameters['f1'], injection_parameters['f2'], injection_parameters['tau1'], injection_parameters['tau2'])**2 * psd_dict[det]
        _sigma_phi1_square += sigma_phi1(injection_parameters['A1'], injection_parameters['f1'], injection_parameters['f2'], injection_parameters['tau1'], injection_parameters['tau2'])**2 * psd_dict[det]
        _sigma_phi2_square += sigma_phi2(injection_parameters['A2'], injection_parameters['f1'], injection_parameters['f2'], injection_parameters['tau1'], injection_parameters['tau2'])**2 * psd_dict[det]

    _sigma_A1 = np.sqrt(_sigma_A1_square)
    _sigma_A2 = np.sqrt(_sigma_A2_square)
    _sigma_f1 = np.sqrt(_sigma_f1_square)
    _sigma_f2 = np.sqrt(_sigma_f2_square)
    _sigma_tau1 = np.sqrt(_sigma_tau1_square)
    _sigma_tau2 = np.sqrt(_sigma_tau2_square)
    _sigma_phi1 = np.sqrt(_sigma_phi1_square)
    _sigma_phi2 = np.sqrt(_sigma_phi2_square)

    return _sigma_A1, _sigma_A2, _sigma_f1, _sigma_f2, _sigma_tau1, _sigma_tau2, _sigma_phi1, _sigma_phi2

def calculate_analitical_iFIM_of_DSparam_from_injection_value(injection_parameters):
    detectors = ['L1', 'H1', 'V1']
    psd_dict = {
        'L1': median_in_band_psd_L1,
        'H1': median_in_band_psd_H1,
        'V1': median_in_band_psd_V1
    }

    _sigma_A1_square = 0
    _sigma_A2_square = 0
    _sigma_f1_square = 0
    _sigma_f2_square = 0
    _sigma_tau1_square = 0
    _sigma_tau2_square = 0
    _sigma_phi1_square = 0
    _sigma_phi2_square = 0
    for det in detectors:
        _sigma_A1_square += sigma_A1(injection_parameters['f1'], injection_parameters['f2'], injection_parameters['tau1'], injection_parameters['tau2'])**2 * psd_dict[det]
        _sigma_A2_square += sigma_A2(injection_parameters['f1'], injection_parameters['f2'], injection_parameters['tau1'], injection_parameters['tau2'])**2 * psd_dict[det]
        _sigma_f1_square += sigma_f1(injection_parameters['A1'], injection_parameters['f1'], injection_parameters['f2'], injection_parameters['tau1'], injection_parameters['tau2'])**2 * psd_dict[det]
        _sigma_f2_square += sigma_f2(injection_parameters['A2'], injection_parameters['f1'], injection_parameters['f2'], injection_parameters['tau1'], injection_parameters['tau2'])**2 * psd_dict[det]
        _sigma_tau1_square += sigma_tau1(injection_parameters['A1'], injection_parameters['f1'], injection_parameters['f2'], injection_parameters['tau1'], injection_parameters['tau2'])**2 * psd_dict[det]
        _sigma_tau2_square += sigma_tau2(injection_parameters['A2'], injection_parameters['f1'], injection_parameters['f2'], injection_parameters['tau1'], injection_parameters['tau2'])**2 * psd_dict[det]
        _sigma_phi1_square += sigma_phi1(injection_parameters['A1'], injection_parameters['f1'], injection_parameters['f2'], injection_parameters['tau1'], injection_parameters['tau2'])**2 * psd_dict[det]
        _sigma_phi2_square += sigma_phi2(injection_parameters['A2'], injection_parameters['f1'], injection_parameters['f2'], injection_parameters['tau1'], injection_parameters['tau2'])**2 * psd_dict[det]

    _sigma_A1 = np.sqrt(_sigma_A1_square)
    _sigma_A2 = np.sqrt(_sigma_A2_square)
    _sigma_f1 = np.sqrt(_sigma_f1_square)
    _sigma_f2 = np.sqrt(_sigma_f2_square)
    _sigma_tau1 = np.sqrt(_sigma_tau1_square)
    _sigma_tau2 = np.sqrt(_sigma_tau2_square)
    _sigma_phi1 = np.sqrt(_sigma_phi1_square)
    _sigma_phi2 = np.sqrt(_sigma_phi2_square)

    return _sigma_A1, _sigma_A2, _sigma_f1, _sigma_f2, _sigma_tau1, _sigma_tau2, _sigma_phi1, _sigma_phi2

def plot_Bayes_Fisher(json_file_path_ver1, json_file_path_ver2):

    """set labels"""
    latex_labels = {
        'mass_1_source': r'$m_{1,\mathrm{source}}\ [M_{\odot}]$',    
        'mass_2_source': r'$m_{2,\mathrm{source}}\ [M_{\odot}]$',    
        'mass_1': r'$m_{1}\ [M_{\odot}]$',    
        'mass_2': r'$m_{2}\ [M_{\odot}]$',    
        'chirp_mass_source': r'$\mathcal{M}_{\mathrm{source}}\ [M_{\odot}]$',
        'chirp_mass': r'$\mathcal{M}\ [M_{\odot}]$',
        'mass_ratio': r'$q$',
        'total_mass_source': r'$m_{\mathrm{total,source}}\ [M_{\odot}]$',
        'symmetric_mass_ratio': r'$\eta$',
        'chi_1': r'$\chi_{\rm 1}$',
        'chi_2': r'$\chi_{\rm 2}$',
        'chi_eff': r'$\chi_{\rm eff}$',
        'luminosity_distance': r'$d_L\ [{\rm Mpc}]$',
        'theta_jn': r'$\iota\ [{\rm rad}]$',
        'cos(iota)': r'$\cos \iota$',
        'sin(iota)': r'$\sin \iota$',
        'sin^2(iota)': r'$\sin^{2} \iota$',
        'geocent_time': r'$t_{c}$',
        'psi': r'$\psi$',
        'phase': r'$\phi$',
        'A_b1': r'$A_{b1}$',
        'A_b2': r'$A_{b2}$',
        'tilde_Ab1': r'$\tilde{A}_{b1}$',
        'tilde_Ab2': r'$\tilde{A}_{b2}$',
        'A1_real': r"$\mathrm{Re}[A_1] \times 10^{-20}$",
        'A1_imag': r"$\mathrm{Im}[A_1] \times 10^{-20}$",
        'alpha_real': r"$\mathrm{Re}[\alpha]$",
        'alpha_imag': r"$\mathrm{Im}[\alpha]$",
        'w1_real': r"$\mathrm{Re}[w_1]$",
        'w1_imag': r"$\mathrm{Im}[w_1]$",
        'w2_real': r"$\mathrm{Re}[w_2]$",
        'w2_imag': r"$\mathrm{Im}[w_2]$",
        'A': r'$A \times 10^{-17}$',
        'A1': r'$A_1 \times 10^{-19}$',
        'A2': r'$A_2 \times 10^{-19}$',
        'alpha': r'$\alpha$',
        'f1': r'$f_1 \ [\mathrm{Hz}]$',
        'f2': r'$f_2 \ [\mathrm{Hz}]$',
        'tau1': r'$\tau_1 \ [\mathrm{s}]$',
        'tau2': r'$\tau_2 \ [\mathrm{s}]$',
        'phi1': r'$\phi_1 \ [\mathrm{rad}]$',
        'phi2': r'$\phi_2 \ [\mathrm{rad}]$',
    }

    """read json file 1"""
    data_ver1 = read(json_file_path_ver1, package='core')
    with open(json_file_path_ver1, 'r') as f:
        others_data_ver1 = json.load(f)
    
    posterior_samples_ver1 = data_ver1.samples_dict.to_pandas()

    injection_parameters_dict_ver1 = data_ver1.injection_parameters
    print(' injection_parameters ver1: {}'.format(injection_parameters_dict_ver1))
    
    keys_to_plot_ver1 = others_data_ver1['search_parameter_keys']
    for key in keys_to_plot_ver1:
        print('plot key of data 1: {}'.format(key))

    if 'fixed_parameter_keys' in others_data_ver1.keys():
        fix_list = others_data_ver1['fixed_parameter_keys']
        for key in fix_list:
            print('not plot key of data 1: {}'.format(key))
    
    if 'deltaf' in keys_to_plot_ver1:
        posterior_samples_ver1['deltaf'] = posterior_samples_ver1['deltaf'] + posterior_samples_ver1['f1']
        posterior_samples_ver1 = posterior_samples_ver1.rename(columns={'deltaf':'f2'})
        injection_parameters_dict_ver1['f2'] = injection_parameters_dict_ver1['deltaf'] + injection_parameters_dict_ver1['f1']
    
    if 'delta_tau' in keys_to_plot_ver1:
        posterior_samples_ver1['delta_tau'] = posterior_samples_ver1['delta_tau'] + posterior_samples_ver1['tau1']
        posterior_samples_ver1 = posterior_samples_ver1.rename(columns={'delta_tau':'tau2'})
        injection_parameters_dict_ver1['tau2'] = injection_parameters_dict_ver1['delta_tau'] + injection_parameters_dict_ver1['tau1']

    Fisher_sigmas_ver1 = calculate_analitical_iFIM_of_DSparam_from_injection_value(injection_parameters_dict_ver1)
    Fisher_sigmas_ver1 = np.array([x * 1e-19 if i in [0, 1] else x for i, x in enumerate(Fisher_sigmas_ver1)])
    Fisher_sigmas_ver1[0] *= 1e-19
    Fisher_sigmas_ver1[1] *= 1e-19
    
    """read json file 2"""
    if json_file_path_ver2 is not None:
        data_ver2 = read(json_file_path_ver2, package='core')
        with open(json_file_path_ver2, 'r') as f:
            others_data_ver2 = json.load(f)
        
        posterior_samples_ver2 = data_ver2.samples_dict.to_pandas()
        
        injection_parameters_dict_ver2 = data_ver2.injection_parameters
        print(' injection_parameters ver2: {}'.format(injection_parameters_dict_ver2))
        
        keys_to_plot_ver2 = others_data_ver2['search_parameter_keys']
        for key in keys_to_plot_ver2:
            print('plot key of data 2: {}'.format(key))
        
        if 'fixed_parameter_keys' in others_data_ver2.keys():
            fix_list = others_data_ver2['fixed_parameter_keys']
        for key in fix_list:
            print('not plot key of data 2: {}'.format(key))
        
        # Fisher_sigmas_ver2 = calculate_analitical_iFIM_of_DSparam_from_injection_value(injection_parameters_dict_ver2)
        # Fisher_sigmas_ver2[0] *= 1e-19
        # Fisher_sigmas_ver2[1] *= 1e-19
        
        """change parameterization from OT to DS or DS to OT"""
        A_pos = posterior_samples_ver2['A'].values
        alpha_pos = posterior_samples_ver2['alpha'].values
        f1_pos = posterior_samples_ver2['f1'].values
        f2_pos = posterior_samples_ver2['f2'].values
        tau1_pos = posterior_samples_ver2['tau1'].values
        tau2_pos = posterior_samples_ver2['tau2'].values
        phi1_pos = posterior_samples_ver2['phi1'].values
        phi2_pos = posterior_samples_ver2['phi2'].values

        w1_pos = 2 * np.pi * f1_pos + 1j / tau1_pos
        w2_pos = 2 * np.pi * f2_pos + 1j / tau2_pos
        delta_w = w2_pos - w1_pos
        
        A1_complex = A_pos / delta_w
        A1 = np.abs(A1_complex)
        phi1_from_amp = np.angle(A1_complex)
        phi1 = phi1_pos + phi1_from_amp
        
        A2_complex = - A_pos * (1 + alpha_pos * delta_w) / delta_w
        A2 = np.abs(A2_complex)
        phi2_from_amp = np.angle(A2_complex)
        phi2 = phi2_pos + phi2_from_amp

        posterior_samples_ver2 = posterior_samples_ver2.drop(columns=['A', 'alpha', 'f1', 'f2', 'tau1', 'tau2', 'phi1', 'phi2'])
        posterior_samples_ver2['A1'] = A1 * 1e2
        posterior_samples_ver2['A2'] = A2 * 1e2
        posterior_samples_ver2['f1'] = f1_pos
        posterior_samples_ver2['f2'] = f2_pos
        posterior_samples_ver2['tau1'] = tau1_pos
        posterior_samples_ver2['tau2'] = tau2_pos
        posterior_samples_ver2['phi1'] = phi1
        posterior_samples_ver2['phi2'] = phi2

    """plot"""
    def format_value(num, precision=3):
        if abs(num) < 0.1 and num != 0:
            return f"{num:.{precision + 2}f}"
        else:
            return f"{num:.{precision}f}"

    for i, key in enumerate(keys_to_plot_ver1):
        pos = posterior_samples_ver1[key]
        if key in latex_labels.keys():
            label = latex_labels[key]
        else:
            label = key

        plt.figure(figsize=(10,6))
        
        sns.kdeplot(data=pos, label=label, fill=False, alpha=0.5, linewidth=1.5, color='C0', density=True)
        
        plt.axvline(injection_parameters_dict_ver1[key], color='red', linestyle='--', label='injection value')

        x_array = np.linspace(np.min(pos), np.max(pos), 10000)
        plt.plot(x_array, norm(injection_parameters_dict_ver1[key], Fisher_sigmas_ver1[i]).pdf(x_array), label='Fisher prediction', color='C1')
        plt.xlabel(label, fontsize=20)
        # plt.ylabel('Probability Density', fontsize=20)

        value = r'${}$'.format(format_value(x_ref, precision=3))
        plt.title(r'{}'.format(value), fontsize=20, color='red')
        
        plt.legend(fontsize=15)
        plt.grid()

        if json_file_path_ver2 is not None and key in keys_to_plot_ver2:
            pos = posterior_samples_ver2[key]
            if key in latex_labels.keys():
                label = latex_labels[key]
            else:
                label = key

            sns.kdeplot(data=pos, label=label, fill=False, alpha=0.5, linewidth=1.5, color='C2')
        
        plt.show()
# Out:
# 'env (Python 3.11.2)' でセルを実行するには、 ipykernel パッケージが必要です。
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Python 環境の作成</a> および必要なパッケージ。

# %%
config_path = 'config/shiftRe_to_220_dw0.1w1_snr100_DSparam.ini'
# config_path = 'config/shiftRe_to_220_dw0.01w1_snr100_DSparam.ini'
# config_path = 'config/shiftRe_to_220_dw0.001w1_snr100_DSparam.ini'
# config_path = 'config/shiftIm_to_220_dw0.1w1_snr100_DSparam.ini'
# config_path = 'config/shiftIm_to_220_dw0.01w1_snr100_DSparam.ini'
# config_path = 'config/shiftIm_to_220_dw0.001w1_snr100_DSparam.ini'


sigmaA1, sigmaA2, sigmaf1, sigmaf2, sigmatau1, sigmatau2, sigmaphi1, sigmaphi2 = calculate_analitical_iFIM_of_DSparam(config_path)
print()
print(f'sigma A1: {sigmaA1}')
print(f'sigma A2: {sigmaA2}')
print(f'sigma f1: {sigmaf1}')
print(f'sigma f2: {sigmaf2}')
print(f'sigma tau1: {sigmatau1}')
print(f'sigma tau2: {sigmatau2}')
print(f'sigma phi1: {sigmaphi1}')
print(f'sigma phi2: {sigmaphi2}')
# Out:
# 15:00 bilby INFO    : mode_number : two_mode
# 15:00 bilby INFO    : A1 : 2.281200654005359
# 15:00 bilby INFO    : A2 : 2.193576170046821
# 15:00 bilby INFO    : alpha : 0.00029552945685847607
# 15:00 bilby INFO    : w1 : (1264.4143462793452-301.02689574732483j)
# 15:00 bilby INFO    : w2 : (1134.4389320257144-301.02689574732483j)
# 15:00 bilby INFO    : delta_w : (-129.9754142536308+0j)
# 15:00 bilby INFO    : delta_w * alpha : (-0.03841156357933093+0j)
# 15:00 bilby INFO    : |delta_w| / |w1| : 0.09999999999999995
# 15:00 bilby INFO    : phi1 : -3.141592653589793
# 15:00 bilby INFO    : phi2 : 0.0
# sigma A1: 4.9037150625789763e-20
# sigma A2: 4.9037150625789763e-20
# sigma f1: 21.979147738880243
# sigma f2: 22.857125674985717
# sigma tau1: 0.0015239829787843848
# sigma tau2: 0.0015848599266200859
# sigma phi1: 2.149620224757071
# sigma phi2: 2.235488846723891

# %%
DS_label = 'shiftRe_to_220_dw0.1w1_snr100_DSparam_delta_tau'
OT_label = 'shiftRe_to_220_dw0.1w1_snr100_OTparam_v3'

json_file_path_DS = f'./outdirs/outdir_{DS_label}/{DS_label}_result.json'
json_file_path_OT = f'./outdirs/outdir_{OT_label}/{OT_label}_result.json'

plot_Bayes_Fisher(json_file_path_DS, json_file_path_OT)
# Out:
# 16:44 bilby WARNING : Prior sampling efficiency is very low, please verify its validity.
#  injection_parameters ver1: {'A1': 0.2281200654005359, 'A2': 0.2193576170046821, 'f1': 201.23779332666524, 'f2': 180.55156366778309, 'tau1': -0.0033219623034593474, 'delta_tau': 0.0, 'phi1': -3.141592653589793, 'phi2': 0.0, 'ra': 0.0, 'dec': 0.0, 'psi': 0.0, 'geocent_time': 0.0, 'reference_frequency': 50.0, 'minimum_frequency': 20.0, 'phi_jl': 0.0, 'phi_12': 0.0, 'H1_matched_filter_snr': (59.639413852775505-0.3645985775335256j), 'H1_optimal_snr': 59.5510119545253, 'L1_matched_filter_snr': (71.29079253596082+0.48333451966272367j), 'L1_optimal_snr': 70.61949750373401, 'V1_matched_filter_snr': (37.85857832065432+0.003430645532106515j), 'V1_optimal_snr': 38.442271613805275, 'fix_list': ['ra', 'dec', 'psi', 'geocent_time'], 'log_likelihood': nan, 'log_prior': nan, 'H1_log_likelihood': nan, 'L1_log_likelihood': nan, 'V1_log_likelihood': nan}
# plot key of data 1: A1
# plot key of data 1: A2
# ...
